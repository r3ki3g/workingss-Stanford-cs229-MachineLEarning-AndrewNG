# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib nbagg

# %%
# Generate some example data
L = 20
x = np.linspace(-L, L, 100*L)     # X values
y = np.linspace(-L, L, 100*L)     # Y values
x, y = np.meshgrid(x, y)          # Create a grid of X and Y values
z1 = np.sqrt(x**2 + y**2)  # Z values (example function)
z2 = np.sqrt(x**2 + y**2 ) + 0.5*x - 10  # Z values (example function)

# %%
# Create a figure and a 3D subplot
fig = plt.figure(dpi=150)
ax = fig.add_subplot(111, projection='3d')

# Create a 3D surface plot
surface1 = ax.plot_surface(x, y, z1, cmap='gray',shade='gouraud',zorder=1)
surface2 = ax.plot_surface(x, y, z2, cmap='gray',shade='gouraud',zorder=2)

# Set labels for the axes
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Set the title
ax.set_title('3D Surface Plot')

# Add a color bar
fig.colorbar(surface, shrink=0.5, aspect=10)

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8232/278821957.py in <module>
#      16
#      17 # Add a color bar
# ---> 18 fig.colorbar(surface, shrink=0.5, aspect=10)
#      19
#      20 # Show the plot
#
# NameError: name 'surface' is not defined
